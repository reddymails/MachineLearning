# %%
can ="Soda"

# %%
can="beans"
can
type(can)
# Out:
# str

# %%
first_name="Ram"
last_name="R"
full = last_name+first_name
print(full)
type(first_name)
# Out:
# RRam
# str

# %%
pizza=100
type(pizza)
# Out:
# int

# %%
appleStock=300.5
type(appleStock)
# Out:
# float

# %%
total = pizza + appleStock
print(total)
type(total)
# Out:
# 400.5
# float

# %%
learn_python=True
type(learn_python)
# Out:
# bool

# %%
#print object id
food = "salad"
print(id(food))
good_food=food
print(id(good_food))

_name = "Sunny"
print(_name.lower())
# Out:
# 2519900818576
# 2519900818576
# sunny
