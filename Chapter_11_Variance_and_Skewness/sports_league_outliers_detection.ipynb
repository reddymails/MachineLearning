# %% [markdown]
# ## Problem Statement
#
#
# You are a data scientist working for a sports analytics company. The dataset, named **"sports_league_data.csv"** includes a variety of attributes for players in the league. The columns in the dataset are as follows:
#
# - **player_id:** A unique identifier for each player.
# - **age:** Age of the player.
# - **position:** The position the player typically plays in (e.g., Forward, Midfielder, Defender, Goalkeeper).
# - **team:** The team the player belongs to.
# - **games_played:** The total number of games played by the player in the season.
# - **player_rating:** An overall performance rating for the player for the season.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# **Import Necessary Libraries**

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task1
#
# 1. Import the data from the "sports_league_data.csv" file.
# 2. display the number of rows and columns.
# 3. Display the first few rows of the dataset to get an overview.

# %%
df = pd.read_csv("sports_league_data.csv")
print(df.shape)
df.head()
# Out:
# (1000, 6)
#   player_id  age    position     team  games_played  player_rating
# 0     P0001   34     Forward  Team 14            29            7.2
# 1     P0002   29    Defender  Team 15            27            8.3
# 2     P0003   31  Goalkeeper   Team 4            39            6.4
# 3     P0004   36  Goalkeeper   Team 6            35            6.6
# 4     P0005   34    Defender  Team 14            26            7.2

# %% [markdown]
# ## Task2:
#
# **Age Analysis:**
# - Mean: Calculate the average age of players in the league.
# - Standard Deviation Intervals:
#     - Calculate the age range within one standard deviation of the mean.
#     - Calculate the age range within two standard deviations of the mean.
#     - Calculate the age range within three standard deviations of the mean.

# %%
#1.mean
mean = int(df['age'].mean())
print("Mean of the age column is:", mean)

#2.calculate standard deviation
std = int(df['age'].std())
print("Std of the age column is:", std)


#mean = round(df.height.mean(),2)
#std = round(df.height.std(),2)

age_left1 =  std - mean
age_right1 = std + mean

age_left2 =  std - 2* mean
age_right2 = std + 2* mean

age_left3 =  std - 3*mean
age_right3 = std + 3*mean

df_age_range_1 = df[(df.age < age_left1 ) | (df.age > age_right1)]
df_age_range_2 = df[(df.age < age_left2 ) | (df.age > age_right2)]
df_age_range_3 = df[(df.age < age_left3 ) | (df.age > age_right3)]

print(df_age_range_1.shape)
print(df_age_range_2.shape)
print(df_age_range_3.shape)
# Out:
# Mean of the age column is: 26
# Std of the age column is: 4
# (179, 6)
# (0, 6)
# (0, 6)

# %% [markdown]
# ## Task3:
#
# **Player Rating Analysis:**
# - Mean: Determine the average player rating across the league.
# - Standard Deviation Intervals:
#     - Calculate the player rating range within one standard deviation of the mean.
#     - Calculate the player rating range within two standard deviations of the mean.
#     - Calculate the player rating range within three standard deviations of the mean.

# %%
mean_for_rating = int(df['player_rating'].mean())
std_for_rating = int(df['player_rating'].mean())
rating_left1 = mean_for_rating - std
rating_right1 = mean_for_rating + std

rating_left2 = mean_for_rating - std * 2
rating_right2 = mean_for_rating + std * 2

rating_left3 = mean_for_rating - std * 3
rating_right3 = mean_for_rating + std * 3

df_rating_1 = df[(df.player_rating > rating_left1) & (df.player_rating < rating_right1)]
df_rating_2 = df[(df.player_rating > rating_left2) & (df.player_rating < rating_right2)]
df_rating_3 = df[(df.player_rating > rating_left3) & (df.player_rating < rating_right3)]
print(df_rating_1.shape)
print(df_rating_2.shape)
print(df_rating_3.shape)
# Out:
# (978, 6)
# (993, 6)
# (1000, 6)

# %% [markdown]
# ## Task4:
#
# Create histogram with Kernel Density Estimation (KDE) plots for both the 'age' and 'player_rating' columns from the dataset. While constructing these plots, ensure to visually represent the standard deviation intervals on the graph.

# %% [markdown]
# - **'age'**

# %%
#By setting KDE (Kernal Density Estimator) we will see that extra  curve..
sns.histplot(df.age, kde=True)

mean = round(df.age.mean(), 2)
std = round(df.age.std(), 2)

print('mean=', mean)
print('std=', std)

# Mean line
plt.axvline(mean, color='k', linestyle='dashed', linewidth=1,
            label=f'Mean = {mean}')

# one standard deviation
plt.axvline(age_right1, color='r', linestyle='dashed', linewidth=1,
            label=f'+1 Std = {age_right1}')
plt.axvline(age_left1, color='r', linestyle='dashed', linewidth=1,
            label=f'-1 Std = {age_left1}')

# two standard deviation
plt.axvline(age_right2, color='g', linestyle='dashed', linewidth=1,
            label=f'+2 Std = {age_right2}')
plt.axvline(age_left2, color='g', linestyle='dashed', linewidth=1,
            label=f'-2 Std = {age_left2}')

# three standard deviation
plt.axvline(age_right3, color='b', linestyle='dashed', linewidth=1,
            label=f'+3 Std = {age_right3}')
plt.axvline(age_left3, color='b', linestyle='dashed', linewidth=1,
            label=f'-3 Std = {age_left3}')

# Show legend
plt.legend()
# Show the plot
# Out:
# mean= 26.85
# std= 4.58

# %% [markdown]
# - **'player_rating'**

# %%
#By setting KDE (Kernal Density Estimator) we will see that extra  curve..
sns.histplot(df.player_rating, kde=True)


# Mean line
plt.axvline(mean_for_rating, color='k', linestyle='dashed', linewidth=1,
            label=f'Mean = {mean_for_rating}')

# one standard deviation
plt.axvline(rating_right1, color='r', linestyle='dashed', linewidth=1,
            label=f'+1 Std = {rating_right1}')
plt.axvline(rating_left1, color='r', linestyle='dashed', linewidth=1,
            label=f'-1 Std = {rating_left1}')

# two standard deviation
plt.axvline(rating_right2, color='g', linestyle='dashed', linewidth=1,
            label=f'+2 Std = {rating_right2}')
plt.axvline(rating_left2, color='g', linestyle='dashed', linewidth=1,
            label=f'-2 Std = {rating_left2}')

# three standard deviation
plt.axvline(rating_right3, color='b', linestyle='dashed', linewidth=1,
            label=f'+3 Std = {rating_right3}')
plt.axvline(rating_left3, color='b', linestyle='dashed', linewidth=1,
            label=f'-3 Std = {rating_left3}')

# Show legend
plt.legend()
# Show the plot

# %% [markdown]
# ## Task5
#
# - Calculate the lower and upper boundaries for the 'Age' and 'Player_Rating' columns.
# - For each column, identify values that fall outside the calculated lower and upper boundaries. These values are considered outliers.

# %% [markdown]
# - **Display age outliers**

# %%
# Print age outliesr which are mean * 3 std

print('Age outliers = ')
df_age_outliers = df[(df.age<age_left3)|(df.age>age_right3)]
print(df_age_outliers)
# Out:
# Age outliers =
# Empty DataFrame
# Columns: [player_id, age, position, team, games_played, player_rating]
# Index: []

# %% [markdown]
# - **Display player_rating outliers**

# %%
print(' player_rating = ')
df_rating_outliers = df[(df.player_rating<rating_left3)|(df.player_rating>rating_right3)]
print(df_rating_outliers)
# Out:
# Age player_rating =
# Empty DataFrame
# Columns: [player_id, age, position, team, games_played, player_rating]
# Index: []

# %% [markdown]
# ## Task6
#
# -  Remove outliers from both the 'age' and 'player_rating' columns and then visualize the adjusted data using histogram plots.

# %%
df_player_rating_no_outliers = df[(df.player_rating>rating_left3)&(df.player_rating<rating_right3)]
print('df_player_rating_no_outliers=',df_player_rating_no_outliers.head(3))
# Out:
# df_player_rating_no_outliers=   player_id  age    position     team  games_played  player_rating
# 0     P0001   34     Forward  Team 14            29            7.2
# 1     P0002   29    Defender  Team 15            27            8.3
# 2     P0003   31  Goalkeeper   Team 4            39            6.4

# %% [markdown]
# - **plot the histograms**

# %%
sns.histplot(df_player_rating_no_outliers['player_rating'], kde=True)
# Out:
# <Axes: xlabel='player_rating', ylabel='Count'>
